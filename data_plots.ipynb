# %%
from plot_data import *

#6/24 detectability test
filename = "data/GB-detectability-6-24.csv"
t_start = "2024-06-24 13:18:00-04:00"
title = "500ppm glovebox detectability at 350C"
vlines = {("2024-06-24 10:55:00-04:00", "start"),("2024-06-24 13:18:00-04:00","restart"),
          ("2024-06-24 13:58:00-04:00","on"), ("2024-06-24 15:03:00-04:00","off")}

plot_data(filename, t_start, title,vlines);
plt.ylim(top = 700, bottom = 0)
# Out:
# Located 'Sample statistics:' at line 6014
# (0.0, 700.0)

# %%
#6/25 detectability test
filename = "data/GB-detectability-6-25.csv"
t_start = "2024-06-25 10:55:00-04:00"
title = "500ppm glovebox detectability at 400C then 500C"
vlines = {("2024-06-25 11:35:00-04:00","start"),
          ("2024-06-25 12:07:00-04:00","on"), ("2024-06-25 13:58:00-04:00","increase"),
          ("2024-06-25 16:02:00-04:00","off")}

plot_data(filename, t_start, title,vlines);
# Out:
# Located 'Sample statistics:' at line 6018

# %%
#6/26 detectability test
filename = "data/GB-detectability-6-26.csv"
t_start = "2024-06-26 12:41:00-04:00"
title = "500ppm glovebox detectability at 600C with varying downstream pressure"
vlines = {
          ("2024-06-26 13:17:00-04:00","on"), ("2024-06-26 15:05:00-04:00","P"),
          ("2024-06-26 16:20:00-04:00","off")}

plot_data(filename, t_start, title,vlines);
# Out:
# Located 'Sample statistics:' at line 5927

# %%
#6/27 dry run
filename = "data/dry_run_6-27.csv"
t_start = "2024-06-27 11:00:00-04:00"
title = "Dry run at 600C with back pressure regulator adjustments"
vlines = {
          ("2024-06-27 12:07:00-04:00","on"), ("2024-06-27 13:30:00-04:00","adjust"),
          ("2024-06-27 15:00:00-04:00","adjust"), ("2024-06-25 15:47:00-04:00", "off")}

plot_data(filename, t_start, title,vlines);
plt.xlim(right = 8)
# Out:
# Located 'Sample statistics:' at line 5965

# %%
#6/28 dry run
filename = "data/dry_run_6-28.csv"
t_start = "2024-06-28 11:30:00-04:00"
title = "Dry run at 600C"
vlines = {("2024-06-28 11:50:00-04:00","on"),
          ("2024-06-28 16:42:00-04:00", "off")}

plot_data(filename, t_start, title,vlines);
# Out:
# Located 'Sample statistics:' at line 4707

# %%
#7/1 dry run
filename = "data/dry_run_600C_07-01.csv"
t_start = "2024-07-01 11:07:00-04:00"
title = "dry run at 600C"
vlines = {("2024-07-01 11:51:00-04:00","flow"),
          ("2024-07-01 12:10:00-04:00", "adjust"),
          ("2024-07-01 15:40:00-04:00", "off")}

plot_data(filename, t_start, title,vlines);
# Out:
# Located 'Sample statistics:' at line 6008

# %%
#7/2 dry run
filename = "data/dry_run_07-02.csv"
t_start = "2024-07-02 11:03:00-04:00"
title = "Dry run at 700C"
vlines = {}

plot_data(filename, t_start, title,vlines);
#plt.savefig("/Users/jaron/Downloads/700_leak.svg")
# Out:
# Located 'Sample statistics:' at line 6013
